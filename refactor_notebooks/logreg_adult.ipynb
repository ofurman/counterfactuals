# %%
import sys
import os

import torch
from matplotlib import pyplot as plt
from torch.utils.data import DataLoader, TensorDataset

# Use os.path to append the project directory to sys.path
project_path = os.path.join(os.path.expanduser("~"), ".programming", "Projects", "counterfactuals")
if project_path not in sys.path:
    sys.path.append(project_path)

from counterfactuals.cf_methods import PPCEF
from counterfactuals.datasets.moons import MoonsDataset
from counterfactuals.losses import BinaryDiscLoss
from counterfactuals.metrics import evaluate_cf
import os
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[3], line 13
#      10 if project_path not in sys.path:
#      11     sys.path.append(project_path)
# ---> 13 from counterfactuals.cf_methods import PPCEF
#      14 from counterfactuals.datasets.moons import MoonsDataset
#      15 from counterfactuals.losses import BinaryDiscLoss
#
# File D:\.programowanie\counterfactuals\counterfactuals\cf_methods\__init__.py:11
#       8 from .group_counterfactual_mixin import GroupCounterfactualMixin
#      10 # Import from subpackages
# ---> 11 from .local import PPCEF, PPCEFR, WACH, WACH_OURS, Artelt
#      12 from .local_counterfactual_mixin import LocalCounterfactualMixin
#      14 global_module = importlib.import_module(".global", package=__package__)
#
# File D:\.programowanie\counterfactuals\counterfactuals\cf_methods\local\__init__.py:10
#       6 #from .cegp.cegp import CEGP
# ...
