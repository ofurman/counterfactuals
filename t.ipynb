# %%
from counterfactuals.datasets import GiveMeSomeCreditDataset

# %%
ds = GiveMeSomeCreditDataset()

# %%
import numpy as np

# %%
np.bincount(ds.y_test)
# Out:
# array([5595,  405])
