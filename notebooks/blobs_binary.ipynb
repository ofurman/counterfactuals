# %%
# %load_ext autoreload
# %autoreload 2

# %%
from cel.datasets import WineDataset

# %%
# ds = BlobsDataset("../data/blobs.csv")
ds = WineDataset("../data/wine.csv")

# %%
ds.raw_data = ds.raw_data[(ds.raw_data["Target"] == 0) | (ds.raw_data["Target"] == 1)]

# %%
ds.raw_data.columns.to_list()
# Out:
# ['Target',
#  ' Alcohol',
#  ' Malic acid',
#  ' Ash',
#  ' Alcalinity of ash',
#  ' Magnesium',
#  ' Total phenols',
#  ' Flavanoids',
#  ' Nonflavanoid phenols',
#  ' Proanthocyanins',
#  ' Color intensity',
#  ' Hue',
#  ' OD280/OD315 of diluted wines',
#  ' Proline']

# %%
ds.raw_data["Target"].unique()
# Out:
# array([0, 1])
