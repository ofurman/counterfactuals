# %%
from pathlib import Path

import numpy as np
import pandas as pd

# %%
root = "../models"

# %%
stat_files = Path(root).rglob("*/ares/metrics_*.csv")

# %%
import re

# %%
def fix_valid_cf_disc(column: pd.Series):
    out=  float(re.search(r"[-+]?\d*\.?\d+", column).group())
    return out

# %%
metric_means = {}

# %%
results = {}

# %%
format_value = lambda x: f"{x:.3g}"

# %%
format_value = lambda x: f"{x:.3g}"

for stat_file in stat_files:
    df = pd.read_csv(stat_file)
    df["valid_cf_disc"] = df["valid_cf_disc"].apply(fix_valid_cf_disc)
    new_df = pd.DataFrame(df.mean()).map(format_value).T.astype(str) + " ± " + pd.DataFrame(df.std()).map(format_value).T.astype(str)
    new_df["Dataset"] = str(stat_file).split("/")[2]
    cols = [new_df.columns[-1]] + list(new_df.columns[:-1])
    new_df = new_df[cols]
    results[str(stat_file)] = new_df

# %%
lr_experiments = []

for experiment in results:
    if "LogisticRegression" in experiment:
        lr_experiments.append(results[experiment])

lr_experiments_df = pd.concat(lr_experiments)
lr_experiments_df
# Out:
#          Dataset model_returned_smth      valid_cf_disc  \
# 0  DigitsDataset               1 ± 0        0.2 ± 0.447
# 0   HelocDataset               1 ± 0  0.00078 ± 0.00174
#
#   dissimilarity_proximity_categorical_hamming  \
# 0                             0.00625 ± 0.014
# 0                                   nan ± nan
#
#   dissimilarity_proximity_categorical_jaccard  \
# 0                             0.0109 ± 0.0243
# 0                                       0 ± 0
#
#   dissimilarity_proximity_continuous_manhatan  \
# 0                                0.371 ± 0.83
# 0                            0.0055 ± 0.00588
#
#   dissimilarity_proximity_continuous_euclidean  \
# 0                                0.297 ± 0.665
# 0                             0.0055 ± 0.00588
#
#   dissimilarity_proximity_continuous_mad distance_l2_jaccard  \
# 0                           0.563 ± 1.26       0.308 ± 0.689
# 0                         0.043 ± 0.0203    0.0055 ± 0.00588
#
#   distance_mad_hamming            sparsity            time  \
# 0         0.569 ± 1.27     0.00625 ± 0.014  0.14 ± 0.00728
# 0            nan ± nan  0.00171 ± 0.000887     15.2 ± 6.94
#
#   flow_log_density_cfs   flow_log_density_xs flow_prob_condition_acc  \
# 0                  NaN                   NaN                     NaN
# 0  -9.7e+06 ± 1.88e+07  -4.88e+03 ± 6.71e+03           0.429 ± 0.303
#
#    lof_scores_xs lof_scores_cfs isolation_forest_scores_xs  \
# 0            NaN            NaN                        NaN
# 0  1.1 ± 0.00471  1.1 ± 0.00837           0.0689 ± 0.00122
#
#   isolation_forest_scores_cfs
# 0                         NaN
# 0           0.0541 ± 0.000445

# %%
mlp_experiments = []

for experiment in results:
    if "MultilayerPerceptron" in experiment:
        mlp_experiments.append(results[experiment])

mlp_experiments_df = pd.concat(mlp_experiments)
mlp_experiments_df
# Out:
#         Dataset model_returned_smth   valid_cf_disc  \
# 0  HelocDataset               1 ± 0  0.0687 ± 0.056
#
#   dissimilarity_proximity_categorical_hamming  \
# 0                                   nan ± nan
#
#   dissimilarity_proximity_categorical_jaccard  \
# 0                                       0 ± 0
#
#   dissimilarity_proximity_continuous_manhatan  \
# 0                           0.00396 ± 0.00235
#
#   dissimilarity_proximity_continuous_euclidean  \
# 0                            0.00396 ± 0.00235
#
#   dissimilarity_proximity_continuous_mad distance_l2_jaccard  \
# 0                        0.0664 ± 0.0488   0.00396 ± 0.00235
#
#   distance_mad_hamming           sparsity flow_log_density_cfs  \
# 0            nan ± nan  0.00209 ± 0.00133         -30.5 ± 12.2
#
#   flow_log_density_xs flow_prob_condition_acc  lof_scores_xs lof_scores_cfs  \
# 0          -16 ± 7.58           0.618 ± 0.116  1.1 ± 0.00471  1.1 ± 0.00557
#
#   isolation_forest_scores_xs isolation_forest_scores_cfs         time
# 0           0.0689 ± 0.00122             0.0496 ± 0.0105  16.3 ± 7.05

# %%
node_experiments = []

for experiment in results:
    if "NODE" in experiment:
        node_experiments.append(results[experiment])

node_experiments_df = pd.concat(node_experiments)
node_experiments_df
# Out:
#         Dataset model_returned_smth      valid_cf_disc  \
# 0  HelocDataset               1 ± 0  0.00074 ± 0.00165
#
#   dissimilarity_proximity_categorical_hamming  \
# 0                                   nan ± nan
#
#   dissimilarity_proximity_categorical_jaccard  \
# 0                                       0 ± 0
#
#   dissimilarity_proximity_continuous_manhatan  \
# 0                           0.00585 ± 0.00495
#
#   dissimilarity_proximity_continuous_euclidean  \
# 0                            0.00585 ± 0.00495
#
#   dissimilarity_proximity_continuous_mad distance_l2_jaccard  \
# 0                        0.0618 ± 0.0499   0.00585 ± 0.00495
#
#   distance_mad_hamming           sparsity flow_log_density_cfs  \
# 0            nan ± nan  0.00277 ± 0.00302         -20.8 ± 18.2
#
#   flow_log_density_xs flow_prob_condition_acc  lof_scores_xs lof_scores_cfs  \
# 0        -18.5 ± 12.1           0.583 ± 0.393  1.1 ± 0.00471  1.1 ± 0.00675
#
#   isolation_forest_scores_xs isolation_forest_scores_cfs         time
# 0           0.0689 ± 0.00122            0.054 ± 0.000272  19.4 ± 7.34

# %%
sdt_experiments = []

for experiment in results:
    if "SDT" in experiment:
        sdt_experiments.append(results[experiment])

sdt_experiments_df = pd.concat(sdt_experiments)
sdt_experiments_df
# Out:
#         Dataset model_returned_smth valid_cf_disc  \
# 0  HelocDataset               1 ± 0         0 ± 0
#
#   dissimilarity_proximity_categorical_hamming  \
# 0                                   nan ± nan
#
#   dissimilarity_proximity_categorical_jaccard  \
# 0                                       0 ± 0
#
#   dissimilarity_proximity_continuous_manhatan  \
# 0                           0.00749 ± 0.00631
#
#   dissimilarity_proximity_continuous_euclidean  \
# 0                            0.00749 ± 0.00631
#
#   dissimilarity_proximity_continuous_mad distance_l2_jaccard  \
# 0                           0.137 ± 0.11   0.00749 ± 0.00631
#
#   distance_mad_hamming           sparsity  flow_log_density_cfs  \
# 0            nan ± nan  0.00342 ± 0.00275  -9.82e+06 ± 1.91e+07
#
#     flow_log_density_xs flow_prob_condition_acc  lof_scores_xs lof_scores_cfs  \
# 0  -4.92e+03 ± 6.78e+03           0.414 ± 0.292  1.1 ± 0.00471  1.1 ± 0.00567
#
#   isolation_forest_scores_xs isolation_forest_scores_cfs         time
# 0           0.0689 ± 0.00122           0.0536 ± 0.000888  19.6 ± 6.94
